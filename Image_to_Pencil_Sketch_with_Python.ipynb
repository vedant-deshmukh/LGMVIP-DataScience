# %% [markdown]
# # LetsGrowMore Virtual Internship Program (LGMVIP) [Sept.2021 - Oct. 2021]
# ## Author : VEDANT DESHMUKH
#
# ## Task 4 : Image to Pencil Sketch with Python
# ### Level: Beginner

# %% [markdown]
# We need to read the image in RBG format and then convert it to a grayscale image. This will turn an image into a classic black and white photo. Then the next thing to do is invert the grayscale image also called negative image, this will be our inverted grayscale image. Inversion can be used to enhance details. Then we can finally create the pencil sketch by mixing the grayscale image with the inverted blurry image. This can be done by dividing the grayscale image by the inverted blurry image. Since images are just arrays, we can easily do this programmatically using the divide function from the cv2 library in Python.

# %% [markdown]
# ### Importing Libraries

# %%
import cv2
from PIL import Image
import matplotlib.pyplot as plt 
# %matplotlib inline

# %% [markdown]
# ### Loading the Image

# %%
img  =  cv2.imread("img.jpg")
img = cv2.resize(img,(500,800))
i_rgb =  cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(i_rgb)

# %% [markdown]
# ### Converting Image to Grayscale

# %%
from IPython.display import display

# %%
grey_img =  cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
display(Image.fromarray(grey_img))
# Out:
# <PIL.Image.Image image mode=L size=500x800 at 0x1EAFEA949A0>

# %% [markdown]
# ### Converting the Image to Negative

# %%
invt_img = cv2.bitwise_not(grey_img)
display(Image.fromarray(invt_img))
# Out:
# <PIL.Image.Image image mode=L size=500x800 at 0x1EAFE4D6D30>

# %% [markdown]
# ### Smoothening the Image

# %%
blur_img = cv2.GaussianBlur(invt_img, (5,5), 0, 0)
display(Image.fromarray(blur_img))
# Out:
# <PIL.Image.Image image mode=L size=500x800 at 0x1EAFE31E730>

# %% [markdown]
# ### Creating the Pencil Sketch

# %%
invt_blur_img = 255 - blur_img
sketch = cv2.divide(grey_img, invt_blur_img, scale=250.0)
display(Image.fromarray(sketch))
# Out:
# <PIL.Image.Image image mode=L size=500x800 at 0x1EAFE3EAEB0>

# %% [markdown]
# ### Comparision between Sketch and Original Image

# %%
i_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(i_rgb)
display(Image.fromarray(sketch))
# Out:
# <PIL.Image.Image image mode=L size=500x800 at 0x1EAB2460070>
